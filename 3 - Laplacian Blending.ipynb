# %%
'''
Script - Do Not Modify

Running this cell will install all the libraries that can be used to solve this
week's Lab. You can make use of any of these libraries to help you in your code.
'''

# !apt-get install python-numpy python-scipy python-matplotlib ipython python-pandas python-sympy python-nose
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
from google.colab import files
from io import BytesIO
from PIL import Image
import cv2
import numpy as np
import scipy
from scipy import signal

# If you get an error regarding the release version of albumentations, Ignore it.
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-lyx javascript-common libamd2 libblosc1 libcamd2 libccolamd2
#   libcholmod3 libcolamd2 libdsdp-5.8gf libgail-common libgail18 libglpk40
#   libgsl23 libgslcblas0 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libjs-jquery-ui libjs-sphinxdoc libjs-underscore libmetis5
#   libsuitesparseconfig5 libumfpack5 python-antlr python-attr
#   python-backports-shutil-get-terminal-size
#   python-backports.functools-lru-cache python-bs4 python-chardet
#   python-configparser python-cvxopt python-cycler python-dateutil
#   python-decorator python-enum34 python-et-xmlfile python-funcsigs
#   python-future python-gmpy python-html5lib python-ipython
#   python-ipython-genutils python-jdcal python-joblib python-lxml
#   python-matplotlib-data python-mock python-mpmath python-numexpr
#   python-olefile python-openpyxl python-pandas-lib python-pathlib2
#   python-patsy python-pbr python-pexpect python-pickleshare python-pil
#   python-pkg-resources python-pluggy python-prompt-toolkit python-ptyprocess
#   python-py python-pyglet python-pygments python-pyparsing python-pytest
#   python-scandir python-simplegeneric python-simplejson python-six
#   python-statsmodels python-statsmodels-lib python-subprocess32 python-tables
#   python-tables-data python-tables-lib python-traitlets python-tz
#   python-wcwidth python-webencodings python-xlrd python-xlwt
#   ttf-bitstream-vera
# Suggested packages:
#   apache2 | lighttpd | httpd libiodbc2-dev default-libmysqlclient-dev
#   gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html gvfs
#   libjs-jquery-ui-docs python-attr-doc python-cvxopt-doc python-cycler-doc
#   python-enum34-doc python-funcsigs-doc python-future-doc python-gmpy-doc
#   python-genshi python-lxml-dbg python-lxml-doc dvipng gir1.2-gtk-3.0
#   ghostscript inkscape python-cairocffi python-configobj python-excelerator
#   python-gobject python-matplotlib-doc python-qt4 python-sip python-tornado
#   python-traits python-wxgtk3.0 texlive-extra-utils texlive-latex-extra
#   ttf-staypuft python-mock-doc python-gmpy2 python-mpmath-doc python-coverage
#   python-nose-doc python-pandas-doc python-patsy-doc python-pexpect-doc
#   python-pil-doc python-pil-dbg python-setuptools subversion
#   python-pytest-xdist python-pyparsing-doc python-scipy-doc
#   python-statsmodels-doc texlive-fonts-extra python-sympy-doc
#   python-tables-doc python-netcdf4 vitables
# The following NEW packages will be installed:
#   fonts-lyx ipython javascript-common libamd2 libblosc1 libcamd2 libccolamd2
#   libcholmod3 libcolamd2 libdsdp-5.8gf libgail-common libgail18 libglpk40
#   libgsl23 libgslcblas0 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libjs-jquery-ui libjs-sphinxdoc libjs-underscore libmetis5
#   libsuitesparseconfig5 libumfpack5 python-antlr python-attr
#   python-backports-shutil-get-terminal-size
#   python-backports.functools-lru-cache python-bs4 python-chardet
#   python-configparser python-cvxopt python-cycler python-dateutil
#   python-decorator python-enum34 python-et-xmlfile python-funcsigs
#   python-future python-gmpy python-html5lib python-ipython
#   python-ipython-genutils python-jdcal python-joblib python-lxml
#   python-matplotlib python-matplotlib-data python-mock python-mpmath
#   python-nose python-numexpr python-olefile python-openpyxl python-pandas
#   python-pandas-lib python-pathlib2 python-patsy python-pbr python-pexpect
#   python-pickleshare python-pil python-pkg-resources python-pluggy
#   python-prompt-toolkit python-ptyprocess python-py python-pyglet
#   python-pygments python-pyparsing python-pytest python-scandir python-scipy
#   python-simplegeneric python-simplejson python-six python-statsmodels
#   python-statsmodels-lib python-subprocess32 python-sympy python-tables
#   python-tables-data python-tables-lib python-traitlets python-tz
#   python-wcwidth python-webencodings python-xlrd python-xlwt
#   ttf-bitstream-vera
# 0 upgraded, 90 newly installed, 0 to remove and 25 not upgraded.
# Need to get 46.0 MB of archives.
# After this operation, 203 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 fonts-lyx all 2.2.4-0ubuntu0.18.04.1 [155 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-decorator all 4.1.2-1 [9,300 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-ptyprocess all 0.5.2-1 [12.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pexpect all 4.2.1-1 [41.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-scandir amd64 1.7-1 [17.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pathlib2 all 2.3.0-1 [15.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pickleshare all 0.7.4-2 [6,832 B]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pkg-resources all 39.0.1-2 [128 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-wcwidth all 0.1.7+dfsg1-1 [14.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-prompt-toolkit all 1.0.15-1 [163 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pygments all 2.2.0+dfsg-1 [577 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-simplegeneric all 0.8.1-1 [11.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-ipython-genutils all 0.2.0-1 [20.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-enum34 all 1.1.6-2 [34.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-traitlets all 4.3.2-1 [59.0 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-backports-shutil-get-terminal-size all 1.0.0-5 [5,024 B]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-ipython all 5.5.0-1 [381 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ipython all 5.5.0-1 [5,284 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparseconfig5 amd64 1:5.1.2-2 [9,044 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libamd2 amd64 1:5.1.2-2 [19.5 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libblosc1 amd64 1.14.2+ds1-1 [31.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcamd2 amd64 1:5.1.2-2 [20.9 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libccolamd2 amd64 1:5.1.2-2 [21.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcolamd2 amd64 1:5.1.2-2 [16.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmetis5 amd64 5.1.0.dfsg-5 [169 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcholmod3 amd64 1:5.1.2-2 [300 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglpk40 amd64 4.65-1 [378 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgslcblas0 amd64 2.4+dfsg-6 [79.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl23 amd64 2.4+dfsg-6 [823 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-underscore all 1.8.3~dfsg-1 [59.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-sphinxdoc all 1.6.7-1ubuntu1 [85.6 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libumfpack5 amd64 1:5.1.2-2 [229 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-antlr all 2.7.7+dfsg-9.2 [19.4 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-attr all 17.4.0-2 [23.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-backports.functools-lru-cache all 1.4-2 [5,960 B]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-chardet all 3.0.4-1 [80.3 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-configparser all 3.5.0-1 [59.6 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdsdp-5.8gf amd64 5.8-9.4 [190 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-cvxopt amd64 1.1.9+dfsg-2build1 [252 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-cycler all 0.10.0-1 [7,520 B]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-dateutil all 2.6.1-1 [60.6 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-et-xmlfile all 1.0.1-2 [8,990 B]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-funcsigs all 1.0.2-4 [13.5 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-future all 0.15.2-4ubuntu2 [335 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-gmpy amd64 1.17-3 [73.1 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-webencodings all 0.5-2 [10.3 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-html5lib all 0.999999999-1 [83.6 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-jdcal all 1.0-1.2 [7,728 B]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-joblib all 0.11-1 [112 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-lxml amd64 4.2.1-1ubuntu0.1 [1,075 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-matplotlib-data all 2.1.1-2ubuntu3 [3,774 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyparsing all 2.2.0+dfsg1-2 [52.1 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-tz all 2018.3-2 [31.6 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-subprocess32 amd64 3.2.7-3 [27.2 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-matplotlib amd64 2.1.1-2ubuntu3 [3,901 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-mpmath all 1.0.0-1 [396 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-nose all 1.3.7-3 [116 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-numexpr amd64 2.6.4-1 [123 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-olefile all 0.45.1-1 [33.2 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-openpyxl all 2.4.9-1 [210 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pandas-lib amd64 0.22.0-4 [3,049 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pandas all 0.22.0-4 [2,764 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-patsy all 0.4.1+git34-ga5b54c2-1ubuntu0.1 [168 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pil amd64 5.1.0-1 [328 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pluggy all 0.6.0-1 [12.2 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-py all 1.5.2-1 [65.1 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pyglet all 1.3.0-1 [1,413 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pytest all 3.3.2-2 [142 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-simplejson amd64 3.13.2-1 [61.2 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-sympy all 1.1.1-5 [2,568 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-tables-lib amd64 3.4.2-4 [408 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-tables-data all 3.4.2-4 [46.1 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pbr all 3.1.1-3ubuntu3 [53.7 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-mock all 2.0.0-3 [47.4 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-tables all 3.4.2-4 [325 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-xlrd all 1.1.0-1 [96.4 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-xlwt all 0.7.5+debian1-1 [83.5 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-scipy amd64 0.19.1-2ubuntu1 [9,689 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-statsmodels-lib amd64 0.8.0-6 [362 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-statsmodels all 0.8.0-6 [6,607 kB]
# Fetched 46.0 MB in 10s (4,836 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-lyx.
# (Reading database ... 134443 files and directories currently installed.)
# Preparing to unpack .../00-fonts-lyx_2.2.4-0ubuntu0.18.04.1_all.deb ...
# Unpacking fonts-lyx (2.2.4-0ubuntu0.18.04.1) ...
# Selecting previously unselected package python-decorator.
# Preparing to unpack .../01-python-decorator_4.1.2-1_all.deb ...
# Unpacking python-decorator (4.1.2-1) ...
# Selecting previously unselected package python-ptyprocess.
# Preparing to unpack .../02-python-ptyprocess_0.5.2-1_all.deb ...
# Unpacking python-ptyprocess (0.5.2-1) ...
# Selecting previously unselected package python-pexpect.
# Preparing to unpack .../03-python-pexpect_4.2.1-1_all.deb ...
# Unpacking python-pexpect (4.2.1-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../04-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-scandir.
# Preparing to unpack .../05-python-scandir_1.7-1_amd64.deb ...
# Unpacking python-scandir (1.7-1) ...
# Selecting previously unselected package python-pathlib2.
# Preparing to unpack .../06-python-pathlib2_2.3.0-1_all.deb ...
# Unpacking python-pathlib2 (2.3.0-1) ...
# Selecting previously unselected package python-pickleshare.
# Preparing to unpack .../07-python-pickleshare_0.7.4-2_all.deb ...
# Unpacking python-pickleshare (0.7.4-2) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../08-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-wcwidth.
# Preparing to unpack .../09-python-wcwidth_0.1.7+dfsg1-1_all.deb ...
# Unpacking python-wcwidth (0.1.7+dfsg1-1) ...
# Selecting previously unselected package python-prompt-toolkit.
# Preparing to unpack .../10-python-prompt-toolkit_1.0.15-1_all.deb ...
# Unpacking python-prompt-toolkit (1.0.15-1) ...
# Selecting previously unselected package python-pygments.
# Preparing to unpack .../11-python-pygments_2.2.0+dfsg-1_all.deb ...
# Unpacking python-pygments (2.2.0+dfsg-1) ...
# Selecting previously unselected package python-simplegeneric.
# Preparing to unpack .../12-python-simplegeneric_0.8.1-1_all.deb ...
# Unpacking python-simplegeneric (0.8.1-1) ...
# Selecting previously unselected package python-ipython-genutils.
# Preparing to unpack .../13-python-ipython-genutils_0.2.0-1_all.deb ...
# Unpacking python-ipython-genutils (0.2.0-1) ...
# Selecting previously unselected package python-enum34.
# Preparing to unpack .../14-python-enum34_1.1.6-2_all.deb ...
# Unpacking python-enum34 (1.1.6-2) ...
# Selecting previously unselected package python-traitlets.
# Preparing to unpack .../15-python-traitlets_4.3.2-1_all.deb ...
# Unpacking python-traitlets (4.3.2-1) ...
# Selecting previously unselected package python-backports-shutil-get-terminal-size.
# Preparing to unpack .../16-python-backports-shutil-get-terminal-size_1.0.0-5_all.deb ...
# Unpacking python-backports-shutil-get-terminal-size (1.0.0-5) ...
# Selecting previously unselected package python-ipython.
# Preparing to unpack .../17-python-ipython_5.5.0-1_all.deb ...
# Unpacking python-ipython (5.5.0-1) ...
# Selecting previously unselected package ipython.
# Preparing to unpack .../18-ipython_5.5.0-1_all.deb ...
# Unpacking ipython (5.5.0-1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../19-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../20-libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../21-libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libblosc1.
# Preparing to unpack .../22-libblosc1_1.14.2+ds1-1_amd64.deb ...
# Unpacking libblosc1 (1.14.2+ds1-1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../23-libcamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../24-libccolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../25-libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../26-libmetis5_5.1.0.dfsg-5_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-5) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../27-libcholmod3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../28-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../29-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../30-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../31-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../32-libglpk40_4.65-1_amd64.deb ...
# Unpacking libglpk40:amd64 (4.65-1) ...
# Selecting previously unselected package libgslcblas0:amd64.
# Preparing to unpack .../33-libgslcblas0_2.4+dfsg-6_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgsl23:amd64.
# Preparing to unpack .../34-libgsl23_2.4+dfsg-6_amd64.deb ...
# Unpacking libgsl23:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../35-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../36-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../37-libjs-underscore_1.8.3~dfsg-1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../38-libjs-sphinxdoc_1.6.7-1ubuntu1_all.deb ...
# Unpacking libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Selecting previously unselected package libumfpack5:amd64.
# Preparing to unpack .../39-libumfpack5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libumfpack5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package python-antlr.
# Preparing to unpack .../40-python-antlr_2.7.7+dfsg-9.2_all.deb ...
# Unpacking python-antlr (2.7.7+dfsg-9.2) ...
# Selecting previously unselected package python-attr.
# Preparing to unpack .../41-python-attr_17.4.0-2_all.deb ...
# Unpacking python-attr (17.4.0-2) ...
# Selecting previously unselected package python-backports.functools-lru-cache.
# Preparing to unpack .../42-python-backports.functools-lru-cache_1.4-2_all.deb ...
# Unpacking python-backports.functools-lru-cache (1.4-2) ...
# Selecting previously unselected package python-bs4.
# Preparing to unpack .../43-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../44-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-configparser.
# Preparing to unpack .../45-python-configparser_3.5.0-1_all.deb ...
# Unpacking python-configparser (3.5.0-1) ...
# Selecting previously unselected package libdsdp-5.8gf.
# Preparing to unpack .../46-libdsdp-5.8gf_5.8-9.4_amd64.deb ...
# Unpacking libdsdp-5.8gf (5.8-9.4) ...
# Selecting previously unselected package python-cvxopt.
# Preparing to unpack .../47-python-cvxopt_1.1.9+dfsg-2build1_amd64.deb ...
# Unpacking python-cvxopt (1.1.9+dfsg-2build1) ...
# Selecting previously unselected package python-cycler.
# Preparing to unpack .../48-python-cycler_0.10.0-1_all.deb ...
# Unpacking python-cycler (0.10.0-1) ...
# Selecting previously unselected package python-dateutil.
# Preparing to unpack .../49-python-dateutil_2.6.1-1_all.deb ...
# Unpacking python-dateutil (2.6.1-1) ...
# Selecting previously unselected package python-et-xmlfile.
# Preparing to unpack .../50-python-et-xmlfile_1.0.1-2_all.deb ...
# Unpacking python-et-xmlfile (1.0.1-2) ...
# Selecting previously unselected package python-funcsigs.
# Preparing to unpack .../51-python-funcsigs_1.0.2-4_all.deb ...
# Unpacking python-funcsigs (1.0.2-4) ...
# Selecting previously unselected package python-future.
# Preparing to unpack .../52-python-future_0.15.2-4ubuntu2_all.deb ...
# Unpacking python-future (0.15.2-4ubuntu2) ...
# Selecting previously unselected package python-gmpy.
# Preparing to unpack .../53-python-gmpy_1.17-3_amd64.deb ...
# Unpacking python-gmpy (1.17-3) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../54-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../55-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-jdcal.
# Preparing to unpack .../56-python-jdcal_1.0-1.2_all.deb ...
# Unpacking python-jdcal (1.0-1.2) ...
# Selecting previously unselected package python-joblib.
# Preparing to unpack .../57-python-joblib_0.11-1_all.deb ...
# Unpacking python-joblib (0.11-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../58-python-lxml_4.2.1-1ubuntu0.1_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../59-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../60-python-matplotlib-data_2.1.1-2ubuntu3_all.deb ...
# Unpacking python-matplotlib-data (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python-pyparsing.
# Preparing to unpack .../61-python-pyparsing_2.2.0+dfsg1-2_all.deb ...
# Unpacking python-pyparsing (2.2.0+dfsg1-2) ...
# Selecting previously unselected package python-tz.
# Preparing to unpack .../62-python-tz_2018.3-2_all.deb ...
# Unpacking python-tz (2018.3-2) ...
# Selecting previously unselected package python-subprocess32.
# Preparing to unpack .../63-python-subprocess32_3.2.7-3_amd64.deb ...
# Unpacking python-subprocess32 (3.2.7-3) ...
# Selecting previously unselected package python-matplotlib.
# Preparing to unpack .../64-python-matplotlib_2.1.1-2ubuntu3_amd64.deb ...
# Unpacking python-matplotlib (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python-mpmath.
# Preparing to unpack .../65-python-mpmath_1.0.0-1_all.deb ...
# Unpacking python-mpmath (1.0.0-1) ...
# Selecting previously unselected package python-nose.
# Preparing to unpack .../66-python-nose_1.3.7-3_all.deb ...
# Unpacking python-nose (1.3.7-3) ...
# Selecting previously unselected package python-numexpr.
# Preparing to unpack .../67-python-numexpr_2.6.4-1_amd64.deb ...
# Unpacking python-numexpr (2.6.4-1) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../68-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-openpyxl.
# Preparing to unpack .../69-python-openpyxl_2.4.9-1_all.deb ...
# Unpacking python-openpyxl (2.4.9-1) ...
# Selecting previously unselected package python-pandas-lib.
# Preparing to unpack .../70-python-pandas-lib_0.22.0-4_amd64.deb ...
# Unpacking python-pandas-lib (0.22.0-4) ...
# Selecting previously unselected package python-pandas.
# Preparing to unpack .../71-python-pandas_0.22.0-4_all.deb ...
# Unpacking python-pandas (0.22.0-4) ...
# Selecting previously unselected package python-patsy.
# Preparing to unpack .../72-python-patsy_0.4.1+git34-ga5b54c2-1ubuntu0.1_all.deb ...
# Unpacking python-patsy (0.4.1+git34-ga5b54c2-1ubuntu0.1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../73-python-pil_5.1.0-1_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1) ...
# Selecting previously unselected package python-pluggy.
# Preparing to unpack .../74-python-pluggy_0.6.0-1_all.deb ...
# Unpacking python-pluggy (0.6.0-1) ...
# Selecting previously unselected package python-py.
# Preparing to unpack .../75-python-py_1.5.2-1_all.deb ...
# Unpacking python-py (1.5.2-1) ...
# Selecting previously unselected package python-pyglet.
# Preparing to unpack .../76-python-pyglet_1.3.0-1_all.deb ...
# Unpacking python-pyglet (1.3.0-1) ...
# Selecting previously unselected package python-pytest.
# Preparing to unpack .../77-python-pytest_3.3.2-2_all.deb ...
# Unpacking python-pytest (3.3.2-2) ...
# Selecting previously unselected package python-simplejson.
# Preparing to unpack .../78-python-simplejson_3.13.2-1_amd64.deb ...
# Unpacking python-simplejson (3.13.2-1) ...
# Selecting previously unselected package python-sympy.
# Preparing to unpack .../79-python-sympy_1.1.1-5_all.deb ...
# Unpacking python-sympy (1.1.1-5) ...
# Selecting previously unselected package python-tables-lib.
# Preparing to unpack .../80-python-tables-lib_3.4.2-4_amd64.deb ...
# Unpacking python-tables-lib (3.4.2-4) ...
# Selecting previously unselected package python-tables-data.
# Preparing to unpack .../81-python-tables-data_3.4.2-4_all.deb ...
# Unpacking python-tables-data (3.4.2-4) ...
# Selecting previously unselected package python-pbr.
# Preparing to unpack .../82-python-pbr_3.1.1-3ubuntu3_all.deb ...
# Unpacking python-pbr (3.1.1-3ubuntu3) ...
# Selecting previously unselected package python-mock.
# Preparing to unpack .../83-python-mock_2.0.0-3_all.deb ...
# Unpacking python-mock (2.0.0-3) ...
# Selecting previously unselected package python-tables.
# Preparing to unpack .../84-python-tables_3.4.2-4_all.deb ...
# Unpacking python-tables (3.4.2-4) ...
# Selecting previously unselected package python-xlrd.
# Preparing to unpack .../85-python-xlrd_1.1.0-1_all.deb ...
# Unpacking python-xlrd (1.1.0-1) ...
# Selecting previously unselected package python-xlwt.
# Preparing to unpack .../86-python-xlwt_0.7.5+debian1-1_all.deb ...
# Unpacking python-xlwt (0.7.5+debian1-1) ...
# Selecting previously unselected package python-scipy.
# Preparing to unpack .../87-python-scipy_0.19.1-2ubuntu1_amd64.deb ...
# Unpacking python-scipy (0.19.1-2ubuntu1) ...
# Selecting previously unselected package python-statsmodels-lib.
# Preparing to unpack .../88-python-statsmodels-lib_0.8.0-6_amd64.deb ...
# Unpacking python-statsmodels-lib (0.8.0-6) ...
# Selecting previously unselected package python-statsmodels.
# Preparing to unpack .../89-python-statsmodels_0.8.0-6_all.deb ...
# Unpacking python-statsmodels (0.8.0-6) ...
# Setting up python-simplejson (3.13.2-1) ...
# Setting up libblosc1 (1.14.2+ds1-1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up python-simplegeneric (0.8.1-1) ...
# Setting up python-attr (17.4.0-2) ...
# Setting up python-scandir (1.7-1) ...
# Setting up libjs-underscore (1.8.3~dfsg-1) ...
# Setting up python-backports.functools-lru-cache (1.4-2) ...
# Setting up python-joblib (0.11-1) ...
# Setting up python-pluggy (0.6.0-1) ...
# Setting up python-tz (2018.3-2) ...
# Setting up python-jdcal (1.0-1.2) ...
# Setting up libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Setting up python-tables-data (3.4.2-4) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up libdsdp-5.8gf (5.8-9.4) ...
# Setting up python-backports-shutil-get-terminal-size (1.0.0-5) ...
# Setting up python-tables-lib (3.4.2-4) ...
# Setting up python-ipython-genutils (0.2.0-1) ...
# Setting up python-configparser (3.5.0-1) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-wcwidth (0.1.7+dfsg1-1) ...
# Setting up python-xlrd (1.1.0-1) ...
# Setting up python-pygments (2.2.0+dfsg-1) ...
# Setting up python-ptyprocess (0.5.2-1) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-et-xmlfile (1.0.1-2) ...
# Setting up python-pandas-lib (0.22.0-4) ...
# Setting up python-pbr (3.1.1-3ubuntu3) ...
# update-alternatives: using /usr/bin/python2-pbr to provide /usr/bin/pbr (pbr) in auto mode
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-5) ...
# Setting up libjs-jquery-ui (1.12.1+dfsg-5) ...
# Setting up python-enum34 (1.1.6-2) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up python-funcsigs (1.0.2-4) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up ttf-bitstream-vera (1.10-8) ...
# Setting up libccolamd2:amd64 (1:5.1.2-2) ...
# Setting up python-statsmodels-lib (0.8.0-6) ...
# Setting up python-decorator (4.1.2-1) ...
# Setting up javascript-common (11) ...
# Setting up python-antlr (2.7.7+dfsg-9.2) ...
# Setting up python-subprocess32 (3.2.7-3) ...
# Setting up python-pathlib2 (2.3.0-1) ...
# Setting up python-traitlets (4.3.2-1) ...
# Setting up libgslcblas0:amd64 (2.4+dfsg-6) ...
# Setting up python-nose (1.3.7-3) ...
# Setting up python-pil:amd64 (5.1.0-1) ...
# Setting up python-mpmath (1.0.0-1) ...
# Setting up python-patsy (0.4.1+git34-ga5b54c2-1ubuntu0.1) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-future (0.15.2-4ubuntu2) ...
# update-alternatives: using /usr/bin/python2-futurize to provide /usr/bin/futurize (futurize) in auto mode
# update-alternatives: using /usr/bin/python2-pasteurize to provide /usr/bin/pasteurize (pasteurize) in auto mode
# Setting up python-gmpy (1.17-3) ...
# Setting up fonts-lyx (2.2.4-0ubuntu0.18.04.1) ...
# Setting up python-pyparsing (2.2.0+dfsg1-2) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up python-numexpr (2.6.4-1) ...
# Setting up python-prompt-toolkit (1.0.15-1) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up python-matplotlib-data (2.1.1-2ubuntu3) ...
# Setting up python-scipy (0.19.1-2ubuntu1) ...
# Setting up python-xlwt (0.7.5+debian1-1) ...
# Setting up libgsl23:amd64 (2.4+dfsg-6) ...
# Setting up python-py (1.5.2-1) ...
# Setting up libcamd2:amd64 (1:5.1.2-2) ...
# Setting up python-mock (2.0.0-3) ...
# Setting up python-pyglet (1.3.0-1) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up python-pexpect (4.2.1-1) ...
# Setting up python-pytest (3.3.2-2) ...
# Setting up python-cycler (0.10.0-1) ...
# Setting up python-dateutil (2.6.1-1) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up python-openpyxl (2.4.9-1) ...
# Setting up python-pickleshare (0.7.4-2) ...
# Setting up python-sympy (1.1.1-5) ...
# Setting up python-tables (3.4.2-4) ...
# Setting up python-html5lib (0.999999999-1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libglpk40:amd64 (4.65-1) ...
# Setting up python-ipython (5.5.0-1) ...
# Setting up python-pandas (0.22.0-4) ...
# Setting up ipython (5.5.0-1) ...
# Setting up python-matplotlib (2.1.1-2ubuntu3) ...
# Setting up libcholmod3:amd64 (1:5.1.2-2) ...
# Setting up python-statsmodels (0.8.0-6) ...
# Setting up libumfpack5:amd64 (1:5.1.2-2) ...
# Setting up python-cvxopt (1.1.9+dfsg-2build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#      |████████████████████████████████| 28.2MB 127kB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
''' 
Script - Do Not Modify

Run this cell and click on the "Choose Files" option and select the two input 
input images 'orange.png and 'apple.png' from your local machine to upload it
to the current session of Google Colab. Enable third party cookies in your 
browser if you encounter any problems while uploading the images.
'''

# Import Images
uploaded = files.upload()
orange = Image.open(BytesIO(uploaded['orange.png']))
apple = Image.open(BytesIO(uploaded['apple.png']))

# Input Image as Numpy Arrays
orange = np.array(orange)
apple = np.array(apple)
# Out:
#      <input type="file" id="files-e75d9b3e-c50d-4a3a-a984-11dc0b8c2bbe" name="files[]" multiple disabled />
#      <output id="result-e75d9b3e-c50d-4a3a-a984-11dc0b8c2bbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving orange.png to orange.png
# Saving apple.png to apple.png

# %%
'''
Function - Do Not Modify

This function is provided to you to use in your solution. You should not modify 
this function. 
'''

def get_gaussian_kernel(size, sigma):
  """
  This function returns a gaussian kernel given size and sigma

  size - number of rows/ no. of cols 
  sigma - standard deviation of the gaussian kernel required
  returns size * size 
  """
  # DO NOT MODIFY
  kernel = np.fromfunction(lambda x, y: (1/(2*np.pi*sigma**2)) * np.e ** ((-1*((x-(size-1)/2)**2+(y-(size-1)/2)**2))/(2*sigma**2)), (size, size))
  kernel /= np.sum(kernel)
  
  return kernel

# %% [markdown]
#     Please follow the instructions to fill in the missing commands.

# %%
'''
Function - Modify

Fill in the expand function
'''

def expand(input_image):

  """
  This function returns The image after the expand operation

  Input: 
    input_image: (m x n x 1)/(m x n x 3)  - The input image (numpy array)

  Output-
    output - (2m x 2n x 1)/(2m x 2n x 3)  - The output image (numpy array)
  
  Some Important Notes:
   - Keep in mind the 3rd dimension of image can either be 1 or 3 so avoid 
     hard coding values. It is a good practice to take most of the data from 
     the inputs (eg. input_image.shape[2])
   - You can use the helper function 'get_gaussian_kernel' provided above in 
     your program
  """

  # 1) Create the expanded image. 
  #    The new image should be twice the size of the original image.
  #    So, for an n x n image you will create an empty 2n x 2n image
  #    Fill every second row and column with the rows and columns of the original
  #    image
  #    i.e., 1st row of I -> 1st row of expanded image
  #          2nd row of I -> 3rd row of expanded image
  #          3rd row of I -> 5th row of expanded image, and so on
  
  # IMPLEMENT THIS FUNCTION HERE
  rows, cols, channels = input_image.shape[0], input_image.shape[1], input_image.shape[2]
  
  # np.zeros((channels, 2 * rows, 2 * cols)) is the traditional way 
  # but this way is much simpler
  expand_image = np.zeros((2 * rows, 2 * cols, channels))
  expand_image[::2, ::2, :] = input_image[:, :, :]

  # 2) Create a Gaussian kernel of size 5x5 and standard deviation equal to 1 
  
  # IMPLEMENT THIS FUNCTION HERE
  G = get_gaussian_kernel(5, 1)

  # 3) Convolve the input image with the filter kernel 
  #    Remember to multiply the output of the filtering with a factor of 4

  # IMPLEMENT THIS FUNCTION HERE
  output = 4 * signal.convolve(expand_image, G[:, :, None], mode='same')
  
  return output

# %%
"""
Script - Do Not Modify

Run this to check the output you are getting for your expand operation. The 
image will be saved on your local device.
"""
from google.colab import files

orange_image = expand(orange)
orange_pil_image = Image.fromarray(orange_image.astype(np.uint8))
orange_pil_image.save('orange_expanded.png')

files.download('orange_expanded.png')

# %%
"""
Test - Do Not Modify

Test Expand Function
"""
expand_correct_output = np.load('expand_output.npy')
#assert(np.array_equal(expand_correct_output, orange_image))
assert(np.allclose(expand_correct_output, orange_image, atol=1e-10))
np.isclose(expand_correct_output, orange_image, atol=1e-10)
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
'''
Function - Modify

Fill in the reduce function
'''
def reduce(input_image):
    
  """
  This funcion returns the image after gaussian blurring and subsampling 
  Input- 
    input_image: (m x n x 1)/(m x n x 3)  - The input image (numpy array)

  Output-
    output - (m/2 x n/2 x 1)/(m/2 x n/2 x 3)  - The output image (numpy array)

  Some Important Notes:
   - Keep in mind the 3rd dimension of image can either be 1 or 3 so avoid 
     hard coding values. It is a good practice to take most of the data from 
     the inputs (eg. input_image.shape[2])
   - You can use the helper functions 'get_gaussian_kernel' provided above in 
     your program
  """
  # 1) Create a Gaussian kernel of size 5x5 and 
  #   standard deviation equal to 1 
  
  # IMPLEMENT THIS FUNCTION HERE
  G = get_gaussian_kernel(5, 1)

  # 2) Convolve the input image with the filter kernel
  #    Tip: Use the default settings of imfilter
  
  # IMPLEMENT THIS FUNCTION HERE
  conv_image = signal.convolve(input_image, G[:, :, None], mode='same')

  # 3) Subsample the image by a factor of 2
  #   i.e., keep only 1st, 3rd, 5th, .. rows and columns

  # IMPLEMENT THIS FUNCTION HERE
  output = conv_image[::2, ::2, :]

  return output

# %%
'''
Script - Do Not Modify

Run this to check the output you are getting for your reduce operation. The 
image will be saved on your local device.
'''

apple_image = reduce(apple)
apple_pil_image = Image.fromarray(apple_image.astype(np.uint8))
apple_pil_image.save('apple_reduced.png')

files.download('apple_reduced.png')

black_and_white = np.zeros((512,512, 1), dtype=float)
black_and_white[:,257:512, :]=1
black_and_white_image = reduce(black_and_white)
black_and_white_image = np.squeeze(black_and_white_image)
black_and_white_pil_image = Image.fromarray((black_and_white_image*255).astype(np.uint8))
black_and_white_pil_image.save('black_and_white.png')

files.download('black_and_white.png')

# %%
'''
Test - Do Not Modify

Test Reduce Function
'''
reduce_correct_output1 = np.load('reduce_output1.npy')
#assert(np.array_equal(reduce_correct_output1, apple_image))
assert(np.allclose(reduce_correct_output1, apple_image, atol=1e-10))
np.isclose(reduce_correct_output1, apple_image, atol=1e-10)

reduce_correct_output2 = np.load('reduce_output2.npy')
#assert(np.array_equal(reduce_correct_output2, black_and_white_image))
assert(np.allclose(reduce_correct_output2, black_and_white_image, atol=1e-10))
np.isclose(reduce_correct_output2, black_and_white_image, atol=1e-10)
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
'''
Function - Modify

Fill in the gaussian_pyramid function to return the appropriate output
'''

def gaussian_pyramid(input_image, depth):
  """
  This function returns the gaussian pyramid of the input image according to 
  the number of depth levels
  
  Input:
  input_image: (m x n x 3)/(m x n x 1) the input image
  depth: number of levels of the Gaussian pyramid
  
  Output: 
  A numpy object array containing all the levels of the Gaussian pyramid 
  Please follow the instructions to fill in the missing commands. 
  """
  gaussian_pyramid = np.empty((depth), dtype=object)

  # IMPLEMENT THIS FUNCTION HERE
  # The first level
  gaussian_pyramid[0] = input_image

  # From the second level to the end
  for i in range(1, depth):
    gaussian_pyramid[i] = reduce(gaussian_pyramid[i - 1])

  return gaussian_pyramid

# %%
'''
Sccript - Do Not Modify

Run this cell to run the gaussian_pyramid function with the orange image and
the depth as given below
'''

orange = Image.open(BytesIO(uploaded['orange.png']))
orange = np.array(orange)

# Depth Levels of the Gaussian Pyramids
depth = 5

gP = gaussian_pyramid(orange, depth)

# %%
'''
Test - Do not modify

Test Gaussian Pyramid Function (Just Check the Last Layer)
'''

gaussian_pyramid_output = np.load('gaussian_pyramid_layer.npy')
#assert(np.array_equal(gaussian_pyramid_output, gP[4]))
assert(np.allclose(gaussian_pyramid_output, gP[4], atol=1e-10))
np.isclose(gaussian_pyramid_output, gP[4], atol=1e-10)
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
'''
Function - Modify

Fill in the laplacian_pyramid function to return the appropriate output
'''

def laplacian_pyramid(input_image, depth):
  
  """
  This function returns the laplacian pyramid of the input image according to 
  the number of depth levels  

  Input:
  input_image: (m x n x 1)/(m x n x 3) the input image
  depth: number of levels of the Laplacian pyramid
  Output:
  L: a numpy object array containing all the levels of the Laplacian pyramid
  """

  # Please follow the instructions to fill in the missing commands.
  
  lp = np.empty((depth), dtype=object)

  # 1) Create a Gaussian pyramid
  # Use the function you already created.
  
  # IMPLEMENT THIS FUNCTION HERE
  gp = gaussian_pyramid(input_image, depth)

  # 2) Create a pyramid, where each level is the corresponding level of
  # the Gaussian pyramid minus the expanded version of the next level of
  # the Gaussian pyramid.
  # Remember that the last level of the Laplacian pyramid is the same as
  # the last level of the Gaussian pyramid.

  # IMPLEMENT THIS FUNCTION HERE
  for i in range(depth - 1):
    lp[i] = gp[i] - expand(gp[i + 1])

  # The last level
  lp[depth - 1] = gp[depth - 1]
      
  return lp

# %%
'''
Script - Do Not Modify

Run this cell to run the laplacian_pyramid function with the orange image and
the depth as given below
'''

orange = Image.open(BytesIO(uploaded['orange.png']))
orange = np.array(orange)

# Depth Levels of the Gaussian Pyramids
depth = 5

lP = laplacian_pyramid(orange, depth)

# %%
'''
Test - Do Not Modify

Test Laplacian Pyramid Function (Just Check the Last Layer)
'''

laplacian_pyramid_output0 = np.load('laplacian_pyramid_layer0.npy')
laplacian_pyramid_output4 = np.load('laplacian_pyramid_layer4.npy')
#assert(np.array_equal(laplacian_pyramid_output4, lP[4]))
assert(np.allclose(laplacian_pyramid_output4, lP[4], atol=1e-10))
np.isclose(laplacian_pyramid_output4, lP[4], atol=1e-10)
#assert(np.array_equal(laplacian_pyramid_output0, lP[0]))
assert(np.allclose(laplacian_pyramid_output0, lP[0], atol=1e-10))
np.isclose(laplacian_pyramid_output0, lP[0], atol=1e-10)
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
'''
Function - Modify

Fill in the combine function to return the appropriate output
'''

def combine(LA, LB, GR):
  
  """
  This function returns the combined Laplacian Pyramid of two input images
  over the Gaussian Pyramid over the selected region

  Input:
  LA: the Laplacian pyramid of the first image
  LB: the Laplacian pyramid of the second image
  GR: Gaussian pyramid of the selected region
  Output:
  LS: Combined Laplacian pyramid
  """

  # Please follow the instructions to fill in the missing commands.
  
  # IMPLEMENT THIS FUNCTION HERE
  depth = LA.shape[0]

  # 1) Combine the Laplacian pyramids of the two images.
  #    For every level d, and every pixel (i,j) the output for the 
  #    combined Laplacian pyramid is of the form:
  #    LS(d,i,j) = GR(d,i,j)*LA(d,i,j) + (1-GR(d,i,j))*LB(d,i,j)
  
  LS = np.empty((depth), dtype=object)

  # IMPLEMENT THIS FUNCTION HERE
  for i in range(depth):
    LS[i] = GR[i] * LA[i] + (1 - GR[i]) * LB[i]
  
  return LS

# %%
'''
Script - Do Not Modify

This script below runs all the functions you have implemented till now. Use this
to check if you are getting any errors in the combine function
'''

# Input Images
orange = Image.open(BytesIO(uploaded['orange.png']))
orange = np.array(orange)
apple = Image.open(BytesIO(uploaded['apple.png']))
apple = np.array(apple)

black_and_white = np.zeros((512,512, 1), dtype=float)
black_and_white[:,257:512, :]=1

# depth of the pyramids
depth = 5

# 1) we build the Laplacian pyramids of the two images
Lorange = laplacian_pyramid(orange,depth)
Lapple = laplacian_pyramid(apple,depth)

# 2) we build the Gaussian pyramid of the selected region
Gblack_and_white = gaussian_pyramid(black_and_white,depth); 
  
  
# 3) we combine the two pyramids using the nodes of GR as weights  
LS = combine(Lorange, Lapple, Gblack_and_white);

# %%
'''
Test - Do Not Modify

Test Combine Output
'''

combine_output = np.load('combine_output.npy')
#assert(np.array_equal(combine_output, LS[4]))
assert(np.allclose(combine_output, LS[4], atol=1e-10))
np.isclose(combine_output, LS[4], atol=1e-10)
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
'''
Function - Modify

Fill in the collapse function to return the appropriate output
'''

def collapse(laplacian_pyramid):
  
  """
  This function collapses the input laplacian pyramid and returns the
  recovered image
  
  Input:
  laplacian_pyramid: the Laplacian pyramid of an image
  Output:
  I: The Recovered image from the Laplacian pyramid
  """

  # Please follow the instructions to fill in the missing commands.
  #
  # 1) Recover the image that is encoded in the Laplacian pyramid
  
  # IMPLEMENT THIS FUNCTION HERE
  depth = laplacian_pyramid.shape[0]

  # From the smaller to the bigger of the Laplacian pyramid
  I = laplacian_pyramid[depth - 1]
  for i in range(depth - 2, -1, -1):
    I = laplacian_pyramid[i] + expand(I)
  
  return I

# %%
'''
Script - Do Not Modify

The script below runs this entire lab to get a blended output of the two images.
It is advised that the learner understand the script and check your output 
image which is downloaded to your local machine when you are successfully able 
to run this function.
'''

# Input Images
orange = Image.open(BytesIO(uploaded['orange.png']))
orange = np.array(orange)
apple = Image.open(BytesIO(uploaded['apple.png']))
apple = np.array(apple)

# Used to define the way we are merging the two images
black_and_white = np.zeros((512,512, 1), dtype=float)
black_and_white[:,257:512, :]=1

# depth of the pyramids
depth = 5

# 1) we build the Laplacian pyramids of the two images
Lorange = laplacian_pyramid(orange,depth)
Lapple = laplacian_pyramid(apple,depth)

# 2) we build the Gaussian pyramid of the selected region
Gblack_and_white = gaussian_pyramid(black_and_white,depth); 
  
  
# 3) we combine the two pyramids using the nodes of GR as weights  
LS = combine(Lorange, Lapple, Gblack_and_white);

# 4) we collapse the output pyramid to get the final blended image
blended_image = collapse(LS)
blended_image = Image.fromarray(blended_image.astype(np.uint8))
blended_image.save('blended_image.png')

# 5) Your output is ready! Download the image to your local machine to check
#    it out!
files.download('blended_image.png')

# %%
'''
Test - Do Not Modify
'''

blended_image_output = np.load('blended_image_output.npy')
#assert(np.array_equal(blended_image_output, blended_image))
# We are dealing with "np.uint8" so we set our tolerance to be 1e-0
assert(np.allclose(blended_image_output, blended_image, atol=1e-0))
np.isclose(blended_image_output, blended_image, atol=1e-0)
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])
