# %% [markdown]
# # Age Estimation
# In this lab, we will implement our own designed Convolutional Neural Network(CNN).
#
# First please download image dataset(APPA-REAL DATABASE) from http://chalearnlap.cvc.uab.es/dataset/26/data/45/description/, and unzip it. Copy this folder to DATASET. The files struction should looks like:
#
# ```
# -----Network
#     |
#     |---- DATASET
#     |    |-- appa-real-release
#     |    |-- valid
#     |    |-- feature_test.npy
#     |    |-- feature_train.npy
#     |    ...
#     |---- helperP.pyc
#     |---- helperT.pyc
#     |---- ignore_list.csv
#     |---- networkCustom.ipynb
#     |---- pynetworkHidden.ipynb
#
#
#
# ```

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from helperT import *

# %% [markdown]
# # Loading Data
# At the heart of PyTorch data loading utility is the torch.utils.data.DataLoader class. It represents a Python iterable over a dataset. The function will return `train_loader`, `val_loader` and `test_loader` three data loaders. The training dataset has 3,995 labeled images, validation dataset has 1,500 labeled images, and testing dataset has 500 imgages, all of these are collected from APPA Dataset.
#
# In the transform function, we will randomly add some Gaussian blur and noise, random flip, crop, rotate also added to traning and validation process. Don't worry, we have already integrated these for you. You can just using an python `enumerate` function to iterate those datasets.

# %%
base_dir = 'DATASET/'
train_loader, val_loader, test_loader = get_img_dataloaders(base_dir)
show_data(base_dir)

# %% [markdown]
# # Network Structure
# The torch.nn  module is the cornerstone of designing neural networks in PyTorch. This class can be used to implement a layer like a fully connected layer, a convolutional layer, a pooling layer, an activation function, and also an entire neural network by instantiating a torch.nn.Module object.
#
# The nn.Module class has two methods that you have to override.
#
# - `__init__ `function. This function is invoked when you create an instance of the nn.Module. Here you will define the various parameters of a layer such as filters, kernel size for a convolutional layer, dropout probability for the dropout layer.
# - `forward` function. This is where you define how your output is computed. This function doesn't need to be explicitly called, and can be run by just calling the nn.Module instance like a function with the input as it's argument.
#
# Another widely used and important class is the nn.Sequential class.  When initiating this class we can pass a list of nn.Module objects in a particular sequence. The object returned by nn.Sequential is itself a nn.Module object. When this object is run with an input, it sequentially runs the input through all the nn.Module object we passed to it, in the very same order as we passed them.
#
# After we defined our computing graph, we have to intitialize our networks's weights. You could try with Xavier initialization, or Kaiming initialization. If you want to get a better score in the end, adding batch normalization to the convolution layers is a good choice.
#
# Here's some class or function might be useful for you:
# - `nn.Conv2d()`
# - `nn.MaxPool2d()`
# - `nn.Sequential()`
# - `nn.AdaptiveAvgPool2d()`
# - `nn.Linear()`
# - `nn.ReLU()`
# - `nn.Dropout()`
#
#
# Our CNN network designed as structure below:
#
# | Layer name | kernel size | padding | activation | stride | (fan_in,fan_out) |
# | ---------- | ----------- | ------- | ---------- | ------ | ---------------- |
# | CONV64     | 7           | 3       | ReLU       |        |       (3,64)     |
# | maxpool    | 2           |         |            | 2      |                  |
# | CONV128-1  | 5           | 2       | ReLU       |        |     (64,128)     |
# | CONV128-2  | 5           | 2       | ReLU       |        |    (128,128)     |
# | maxpool    | 2           |         |            | 2      |                  |
# | CONV256-1  | 3           | 1       | ReLU       |        |    (128,256)     |
# | CONV256-2  | 3           | 1       | ReLU       |        |    (256,256)     |
# | CONV256-3  | 3           | 1       | ReLU       |        |    (256,256)     |
# | maxpool    | 2           |         |            | 2      |                  |
# | CONV512-1  | 3           | 1       | ReLU       |        |    (256,512)     |
# | CONV512-2  | 3           | 1       | ReLU       |        |    (512,512)     |
# | CONV512-3  | 3           | 1       | ReLU       |        |    (512,512)     |
# | maxpool    | 2           |         |            | 2      |                  |
# | CONV512-4  | 3           | 1       | ReLU       |        |    (512,512)     |
# | CONV512-5  | 3           | 1       | ReLU       |        |    (512,512)     |
# | CONV512-6  | 3           | 1       | ReLU       |        |    (512,512)     |
# | maxpool    | 2           |         |            | 2      |                  |
# | FC1        |             |         | ReLU       |        |  (512x4x4,4096)  |
# | FC2        |             |         | ReLU       |        |    (4096,4096)   |
# | FC3        |             |         |            |        |    (4096,101)    |

# %%
'''
 INPUTS   ---------------->  128x128x64  ---------------->  64x64x64   
128x128x3     CONV-64              maxpool                       

  ---------------->  64x64x128   ---------------->  64x64x128  ---------------->  32x32x128
    CONV128-1             CONV128-2             maxpool
  
  ---------------->  32x32x256   ---------------->  32x32x256   ---------------->  32x32x256  ---------------->  16x16x256
    CONV256-1             CONV256-2             CONV256-3             maxpool
       
  ---------------->  16x16x512   ---------------->  16x16x512   ---------------->  16x16x512  ---------------->   8x8x512
    CONV512-1             CONV512-2             CONV512-3             maxpool

  ---------------->    8x8x512   ---------------->   8x8x512  ---------------->   8x8x512   ---------------->   4x4x512
    CONV512-4             CONV512-5             CONV512-6             maxpool
  
  4x4x512 ----------->  FC1  -----------> FC2  ----------->  FC3
              4096        4096          101

'''
# Out:
# '\n INPUTS   ---------------->  128x128x64  ---------------->  64x64x64   \n128x128x3     CONV-64              maxpool                       \n\n  ---------------->  64x64x128   ---------------->  64x64x128  ---------------->  32x32x128\n    CONV128-1             CONV128-2             maxpool\n  \n  ---------------->  32x32x256   ---------------->  32x32x256   ---------------->  32x32x256  ---------------->  16x16x256\n    CONV256-1             CONV256-2             CONV256-3             maxpool\n       \n  ---------------->  16x16x512   ---------------->  16x16x512   ---------------->  16x16x512  ---------------->   8x8x512\n    CONV512-1             CONV512-2             CONV512-3             maxpool\n\n  ---------------->    8x8x512   ---------------->   8x8x512  ---------------->   8x8x512   ---------------->   4x4x512\n    CONV512-4             CONV512-5             CONV512-6             maxpool\n  \n  4x4x512 ----------->  FC1  -----------> FC2  ----------->  FC3\n              4096        4096          101\n\n'

# %%
class AgeNet(nn.Module):
        def __init__(self):
            super(AgeNet, self).__init__()
            ##########################################################################
            # TODO: YOUR CODE HERE
            ##########################################################################        
            # define the network
            self.features = nn.Sequential(
                # Layer 1
                nn.Conv2d(3, 64, kernel_size=7, stride=1, padding=3), 
                nn.ReLU(), 
                nn.MaxPool2d(kernel_size=2, stride=2), 
                # Layer 2
                nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=2), 
                nn.ReLU(), 
                nn.Conv2d(128, 128, kernel_size=5, stride=1, padding=2), 
                nn.ReLU(), 
                nn.MaxPool2d(kernel_size=2, stride=2), 
                # Layer 3
                nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.MaxPool2d(kernel_size=2, stride=2), 
                # Layer 4
                nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.MaxPool2d(kernel_size=2, stride=2), 
                # Layer 5
                nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), 
                nn.ReLU(), 
                nn.MaxPool2d(kernel_size=2, stride=2)
            )
            self.classifier = nn.Sequential(
                # Layer 6
                nn.Linear(512 * 4 * 4, 4096), 
                nn.ReLU(), 
                # Layer 7
                nn.Linear(4096, 4096), 
                nn.ReLU(), 
                # Layer 8
                nn.Linear(4096, 101)
            )
        
            self._initialize_weights()

        def forward(self, x):
            ##########################################################################
            # TODO: YOUR CODE HERE
            ##########################################################################
            # forward calculation
            x = self.features(x)
            x = x.view(x.size(0), -1)  # 512 * 4 * 4 = 8192
            
            output = self.classifier(x)
            return output

        def _initialize_weights(self):
            for m in self.modules():
                if isinstance(m, nn.Conv2d):
                    nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                    if m.bias is not None:
                        nn.init.constant_(m.bias, 0)
                elif isinstance(m, nn.BatchNorm2d):
                    nn.init.constant_(m.weight, 1)
                    nn.init.constant_(m.bias, 0)
                elif isinstance(m, nn.Linear):
                    nn.init.normal_(m.weight, 0, 0.01)
                    nn.init.constant_(m.bias, 0)

# %% [markdown]
# # Training and validation

# %%
def train_ageNet():

    # set the parameters for optimization (all should be kept same)
    EPOCH  = 100
    TRAIN_LR = 0.001   #Learning rate
    MOMENTUM = 0.9    #SGD Momemutm


    ##########################################################################
    # TODO: YOUR CODE HERE
    ##########################################################################   
    # Set the random seed
    np.random.seed(1)
    
    # Instantiate the AgeNet
    model = AgeNet()
    print(model)

    # Move the model to gpu (in Colab you have one)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Define the SGD optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=TRAIN_LR, momentum=MOMENTUM)
    
    # Define the criterion
    criterion = torch.nn.CrossEntropyLoss()

    # Set the intial value for validation error
    loss_opt = 1e6

    for e in range(EPOCH):
        # Training
        model.train()

        ##########################################################################
        # TODO: YOUR CODE HERE
        ########################################################################## 
        for i, (y, x) in enumerate(train_loader):
            x, y = x.cuda(), y.cuda().long()
            # Zero the parameter gradients
            optimizer.zero_grad()

            # Calculate the forward pass
            outputs = model(x)

            # Calculate the gradient and update the model
            loss = criterion(outputs, y)
            loss.backward()
            optimizer.step()

        ##########################################################################
        # TODO: YOUR CODE HERE
        ########################################################################## 
        # Validationu
        model.eval()
        gtsVal = []     # save all the ground truth for validation set (saved in numpy format)
        predsVal = []   # save all the  predictions for validation set (saved in numpy format)

        for i, (y, x) in enumerate(val_loader):
            x, y = x.cuda(), y.cuda().long()
            # calculate the predictions on validation set
            outputs = model(x)
            loss = criterion(outputs, y)
            _, predicted = torch.max(outputs, 1)

            # save the predictions for validation sets and ground truth
            predsVal.append(predicted.cpu().detach().numpy())
            gtsVal.append(y.cpu().numpy())

        # change prediction and ground truth to numpy
        predsVal = np.concatenate(predsVal, axis=0)
        gtsVal = np.concatenate(gtsVal, axis=0)

        ##########################################################################
        # TODO: YOUR CODE HERE
        ########################################################################## 
        # calculate the mean absolute error on validation set
        mae = np.abs(predsVal - gtsVal).mean()

        ##########################################################################
        # TODO: YOUR CODE HERE
        ########################################################################## 
        if(mae < loss_opt):
            loss_opt = mae
            # save the model if mae reaches the optimum
            checkpoint = {'net': model.state_dict()}
            torch.save(checkpoint, '/content/drive/My Drive/CIS 581/Project 9/net_checkpoint.pt')
        print("=> [epoch", format(e + 1, "04") + "] mae validation:", format(mae, ".5f"), "loss:", format(loss.item(), ".3f"))

    print("=> training finished")
    return predsVal, gtsVal

# %%
#if __name__ == "__main__":
print(torch.cuda.is_available())
preds, gt = train_ageNet()
show_results(preds, gt)
# Out:
# True
# AgeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU()
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU()
#     (28): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=101, bias=True)
#   )
# )
# => [epoch 0001] mae validation: 11.21333 loss: 3.575
# => [epoch 0002] mae validation: 12.18667 loss: 3.808
# => [epoch 0003] mae validation: 11.57333 loss: 3.658
# => [epoch 0004] mae validation: 12.18667 loss: 3.697
# => [epoch 0005] mae validation: 11.21067 loss: 3.647
# => [epoch 0006] mae validation: 11.38933 loss: 3.620
# => [epoch 0007] mae validation: 11.21333 loss: 3.522
# => [epoch 0008] mae validation: 12.38733 loss: 3.602
# => [epoch 0009] mae validation: 11.20667 loss: 3.687
# => [epoch 0010] mae validation: 11.79933 loss: 3.772
# => [epoch 0011] mae validation: 11.69933 loss: 3.605
# => [epoch 0012] mae validation: 11.23200 loss: 3.546
# => [epoch 0013] mae validation: 11.71133 loss: 3.599
# => [epoch 0014] mae validation: 12.76800 loss: 3.520
# => [epoch 0015] mae validation: 12.74333 loss: 3.576
# => [epoch 0016] mae validation: 12.58800 loss: 3.642
# => [epoch 0017] mae validation: 13.78800 loss: 3.632
# => [epoch 0018] mae validation: 13.10200 loss: 3.631
# => [epoch 0019] mae validation: 11.91933 loss: 3.530
# => [epoch 0020] mae validation: 11.80800 loss: 3.476
# => [epoch 0021] mae validation: 12.27400 loss: 3.548
# => [epoch 0022] mae validation: 12.10200 loss: 3.577
# => [epoch 0023] mae validation: 12.24600 loss: 3.484
# => [epoch 0024] mae validation: 10.87133 loss: 3.543
# => [epoch 0025] mae validation: 11.10533 loss: 3.444
# => [epoch 0026] mae validation: 11.56867 loss: 3.545
# => [epoch 0027] mae validation: 11.69733 loss: 3.595
# => [epoch 0028] mae validation: 10.89000 loss: 3.502
# => [epoch 0029] mae validation: 10.06400 loss: 3.522
# => [epoch 0030] mae validation: 10.76867 loss: 3.575
# => [epoch 0031] mae validation: 9.70733 loss: 3.492
# => [epoch 0032] mae validation: 11.07867 loss: 3.692
# => [epoch 0033] mae validation: 9.92800 loss: 3.651
# => [epoch 0034] mae validation: 9.91667 loss: 3.551
# => [epoch 0035] mae validation: 9.24867 loss: 3.558
# => [epoch 0036] mae validation: 9.99933 loss: 3.583
# => [epoch 0037] mae validation: 9.62733 loss: 3.583
# => [epoch 0038] mae validation: 9.72667 loss: 3.700
# => [epoch 0039] mae validation: 9.24400 loss: 3.662
# => [epoch 0040] mae validation: 8.95067 loss: 3.591
# => [epoch 0041] mae validation: 9.05867 loss: 3.476
# => [epoch 0042] mae validation: 8.99667 loss: 3.510
# => [epoch 0043] mae validation: 8.80067 loss: 3.518
# => [epoch 0044] mae validation: 8.59467 loss: 3.508
# => [epoch 0045] mae validation: 8.93400 loss: 3.646
# => [epoch 0046] mae validation: 8.67067 loss: 3.357
# => [epoch 0047] mae validation: 8.73933 loss: 3.456
# => [epoch 0048] mae validation: 8.77333 loss: 3.635
# => [epoch 0049] mae validation: 9.27267 loss: 3.602
# => [epoch 0050] mae validation: 9.62800 loss: 3.491
# => [epoch 0051] mae validation: 8.98400 loss: 3.455
# => [epoch 0052] mae validation: 8.45400 loss: 3.601
# => [epoch 0053] mae validation: 8.59600 loss: 3.446
# => [epoch 0054] mae validation: 8.44200 loss: 3.642
# => [epoch 0055] mae validation: 8.23733 loss: 3.449
# => [epoch 0056] mae validation: 8.16867 loss: 3.610
# => [epoch 0057] mae validation: 8.68533 loss: 3.676
# => [epoch 0058] mae validation: 8.48267 loss: 3.517
# => [epoch 0059] mae validation: 7.98200 loss: 3.507
# => [epoch 0060] mae validation: 8.76733 loss: 3.816
# => [epoch 0061] mae validation: 8.19800 loss: 3.578
# => [epoch 0062] mae validation: 8.24600 loss: 3.584
# => [epoch 0063] mae validation: 8.30467 loss: 3.486
# => [epoch 0064] mae validation: 8.06600 loss: 3.407
# => [epoch 0065] mae validation: 8.12667 loss: 3.393
# => [epoch 0066] mae validation: 7.80267 loss: 3.343
# => [epoch 0067] mae validation: 8.66333 loss: 3.573
# => [epoch 0068] mae validation: 8.24800 loss: 3.439
# => [epoch 0069] mae validation: 8.42867 loss: 3.587
# => [epoch 0070] mae validation: 8.09533 loss: 3.492
# => [epoch 0071] mae validation: 7.80467 loss: 3.528
# => [epoch 0072] mae validation: 8.21333 loss: 3.636
# => [epoch 0073] mae validation: 8.16667 loss: 3.617
# => [epoch 0074] mae validation: 8.35200 loss: 3.566
# => [epoch 0075] mae validation: 7.96000 loss: 3.638
# => [epoch 0076] mae validation: 7.54467 loss: 3.400
# => [epoch 0077] mae validation: 8.00000 loss: 3.466
# => [epoch 0078] mae validation: 7.84067 loss: 3.608
# => [epoch 0079] mae validation: 7.89933 loss: 3.549
# => [epoch 0080] mae validation: 7.90467 loss: 3.736
# => [epoch 0081] mae validation: 7.76667 loss: 3.349
# => [epoch 0082] mae validation: 7.86933 loss: 3.637
# => [epoch 0083] mae validation: 8.06800 loss: 3.328
# => [epoch 0084] mae validation: 8.11067 loss: 3.674
# => [epoch 0085] mae validation: 8.07000 loss: 3.711
# => [epoch 0086] mae validation: 8.18000 loss: 3.341
# => [epoch 0087] mae validation: 7.93933 loss: 3.547
# => [epoch 0088] mae validation: 7.86067 loss: 3.634
# => [epoch 0089] mae validation: 7.78000 loss: 3.499
# => [epoch 0090] mae validation: 7.59800 loss: 3.638
# => [epoch 0091] mae validation: 7.58533 loss: 3.464
# => [epoch 0092] mae validation: 7.59133 loss: 3.648
# => [epoch 0093] mae validation: 7.59067 loss: 3.507
# => [epoch 0094] mae validation: 7.46867 loss: 3.629
# => [epoch 0095] mae validation: 8.13267 loss: 3.703
# => [epoch 0096] mae validation: 7.22800 loss: 3.690
# => [epoch 0097] mae validation: 7.43733 loss: 3.566
# => [epoch 0098] mae validation: 7.68867 loss: 3.643
# => [epoch 0099] mae validation: 7.47667 loss: 3.606
# => [epoch 0100] mae validation: 7.38667 loss: 3.442
# => training finished

# %% [markdown]
# # Test and Generate results file

# %%
##########################################################################
# TODO: YOUR CODE HERE
########################################################################## 
# Load in the model saved in training process
model = AgeNet()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
checkpoint = torch.load('/content/drive/My Drive/CIS 581/Project 9/net_checkpoint.pt')
model.load_state_dict(checkpoint['net'])

# Do the test
prediction = test_cel(model, test_loader, "custom.txt")
print("Test results has saved to custom.txt")
print(prediction[:10])
# Out:
# Test results has saved to custom.txt
# [24.86185712 55.7724095  31.04371666 19.0354988  22.16587909 28.04422481
#  29.22789776 47.37319813 28.01524731 42.14522534]
